# %% [markdown]
# **Understanding Logistic Regression in Python**

# %%
#Rajan kumar
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Colab Notebooks/Machine Learning/Logistic regression
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Machine Learning/Logistic regression

# %%
ls
# Out:
#  pima-indians-diabetes.csv  'winequality 3.csv'    winequalityleveldata.csv
#  practise.ipynb              winequality.csv
#  Untitled0.ipynb            'Wine quality.ipynb'

# %%
#Rajan kumar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
col_names = ['type', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulphur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
# load dataset
data_set = pd.read_csv("winequality.csv", header=None, names=col_names)

# %%
#Rajan kumar
data_set.head()
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            7.0              0.27         0.36            20.7
# 1     1            6.3              0.30         0.34             1.6
# 2     1            8.1              0.28         0.40             6.9
# 3     1            7.2              0.23         0.32             8.5
# 4     1            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulphur dioxide  density    pH  \
# 0      0.045                 45.0                  170.0   1.0010  3.00
# 1      0.049                 14.0                  132.0   0.9940  3.30
# 2      0.050                 30.0                   97.0   0.9951  3.26
# 3      0.058                 47.0                  186.0   0.9956  3.19
# 4      0.058                 47.0                  186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %% [markdown]
# **Selecting Feature**
# Here, you need to divide the given columns into two types of variables dependent(or target variable) and independent variable(or feature variables or attributes).

# %%
#Rajan kumar
#split dataset in attribute and target variable
attribute_cols = ['type', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulphur dioxide', 'density', 'pH', 'sulphates', 'alcohol']
X = data_set[attribute_cols] # Features
Y = data_set.quality # Target variable
print(X)
print(Y)
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.0             0.270         0.36            20.7
# 1        1            6.3             0.300         0.34             1.6
# 2        1            8.1             0.280         0.40             6.9
# 3        1            7.2             0.230         0.32             8.5
# 4        1            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6493     2            6.2             0.550         0.10             2.2
# 6494     2            5.9             0.510         0.13             2.3
# 6495     2            6.3             0.645         0.12             2.0
# 6496     2            5.9             0.310         0.47             3.6
# 6497     0            6.0             0.000         0.00             0.0
#
#       chlorides  free sulfur dioxide  total sulphur dioxide  density    pH  \
# ...

# %%
#Rajan kumar
#After split in X
X.head(10)
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            2.0              0.22         0.32            20.2
# 1     1            2.3              0.30         0.31             1.2
# 2     1            3.1              0.23         0.10             2.3
# 3     1            2.2              0.23         0.32             3.1
# 4     1            2.2              0.23         0.32             3.1
# 5     1            3.1              0.23         0.10             2.3
# 6     1            2.2              0.32         0.12             2.0
# 7     1            2.0              0.22         0.32            20.2
# 8     1            2.3              0.30         0.31             1.2
# 9     1            3.1              0.22         0.13             1.1
#
#    chlorides  free sulfur dioxide  total sulphur dioxide  density    pH  \
# 0      0.011                 11.0                  120.0   1.0010  3.00
# ...

# %%
#Rajan kumar
#After split in Y
Y.head(10)
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    6
# 7    6
# 8    6
# 9    6
# Name: quality, dtype: int64

# %% [markdown]
# **Splitting Data**
# To understand model performance, dividing the dataset into a training set and a test set is a good strategy.
#
# Let's split dataset by using function train_test_split(). You need to pass 3 parameters features, target, and test_set size. Additionally, you can use random_state to select records randomly.

# %%
#Rajan kumar
#split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 3733     1            7.5             0.190         0.34             1.6
# 1651     1            7.6             0.420         0.74            12.8
# 5061     2            7.8             0.600         0.26             7.3
# 1303     1            7.4             0.200         0.36             8.1
# 474      1            7.0             0.160         0.22             4.5
# ...    ...            ...               ...          ...             ...
# 4931     2            8.3             0.605         0.12            10.7
# 3264     1            6.5             0.240         0.12             1.4
# 1653     1            8.2             0.330         0.28            31.6
# 2607     1            7.2             0.260         0.33             8.1
# 2732     1            7.9             0.510         0.34             2.6
#
#       chlorides  free sulfur dioxide  total sulphur dioxide  density    pH  \
# ...

# %%
#Rajan kumar
X_train.head()
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 3733     1            7.5              0.19         0.34             1.6
# 1651     1            7.6              0.42         0.74            12.8
# 5061     2            7.8              0.60         0.26             7.3
# 1303     1            7.4              0.20         0.36             8.1
# 474      1            7.0              0.16         0.22             4.5
#
#       chlorides  free sulfur dioxide  total sulphur dioxide  density    pH  \
# 3733      0.029                 39.0                  116.0  0.98954  3.21
# 1651      0.076                 48.0                  209.0  0.99780  3.12
# 5061      0.070                 36.0                  121.0  0.99820  3.37
# 1303      0.035                 60.0                  163.0  0.99520  3.05
# 474       0.030                 30.0                  102.0  0.99380  3.24
#
#       sulphates  alcohol
# 3733       0.68     12.5
# ...

# %%
#Rajan kumar
X_test.head()
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 5602     2            7.5             0.765         0.04             1.6
# 3609     1            7.0             0.160         0.25            14.3
# 3520     1            6.9             0.230         0.15             9.7
# 1622     1            8.9             0.440         0.49             7.7
# 2443     1            7.6             0.320         0.33             2.5
#
#       chlorides  free sulfur dioxide  total sulphur dioxide  density    pH  \
# 5602      0.078                  4.0                   14.0  0.99800  3.29
# 3609      0.044                 27.0                  149.0  0.99800  2.91
# 3520      0.048                101.0                  207.0  0.99571  3.05
# 1622      0.045                 16.0                  169.0  0.99570  3.11
# 2443      0.052                 40.0                  219.5  0.99316  3.15
#
#       sulphates  alcohol
# 5602       0.54      9.7
# ...

# %%
#Rajan kumar
y_train.head()
# Out:
# 3733    6
# 1651    6
# 5061    5
# 1303    6
# 474     6
# Name: quality, dtype: int64

# %%
#Rajan kumar
y_test.head()
# Out:
# 5602    4
# 3609    6
# 3520    5
# 1622    6
# 2443    5
# Name: quality, dtype: int64

# %% [markdown]
# Here, the Dataset is broken into two parts in a ratio of 75:25. It means 75% data will be used for model training and 25% for model testing.
#
# **Model Development and Prediction**
# First, import the Logistic Regression module and create a Logistic Regression classifier object using LogisticRegression() function.
#
# Then, fit your model on the train set using fit() and perform prediction on the test set using predict().

# %%
#Rajan kumar
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# **Model Evaluation using Confusion Matrix**
# A confusion matrix is a table that is used to evaluate the performance of a classification model. You can also visualize the performance of an algorithm. The fundamental of a confusion matrix is the number of correct and incorrect predictions are summed up class-wise.

# %%
#Rajan kumar
# import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[  0,   0,   4,   6,   0,   0],
#        [  0,   0,  13,  44,   1,   0],
#        [  0,   0, 208, 345,   2,   0],
#        [  0,   0, 130, 566,   2,   0],
#        [  0,   0,  21, 238,   0,   0],
#        [  0,   0,   3,  41,   1,   0]])

# %% [markdown]
# Here, you can see the confusion matrix in the form of the array object. The dimension of this matrix is 6*6 because this model is miltinomial classification. Diagonal values represent accurate predictions, while non-diagonal elements are inaccurate predictions.
#
# Visualizing Confusion Matrix using Heatmap
# Let's visualize the results of the model in the form of a confusion matrix using matplotlib and seaborn.
#
# Here, you will visualize the confusion matrix using Heatmap.

# %%
#Rajan kumar
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Rajan kumar
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %% [markdown]
# **Confusion Matrix Evaluation Metrics**
# Let's evaluate the model using model evaluation metrics such as accuracy, precision, and recall.

# %%
#Rajan kumar
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
#print("Precision:",metrics.precision_score(y_test, y_pred))
#print("Recall:",metrics.recall_score(y_test, y_pred))

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4763076923076923
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00        10
#            4       0.00      0.00      0.00        58
#            5       0.55      0.37      0.45       555
#            6       0.46      0.81      0.58       698
#            7       0.00      0.00      0.00       259
#            8       0.00      0.00      0.00        45
#
#     accuracy                           0.48      1625
#    macro avg       0.17      0.20      0.17      1625
# weighted avg       0.38      0.48      0.40      1625
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# **ROC Curve**
# Receiver Operating Characteristic(ROC) curve is a plot of the true positive rate against the false positive rate. It shows the tradeoff between sensitivity and specificity.
